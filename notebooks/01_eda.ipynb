# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel('/Users/sura/churnguard-api/data/raw/Telco_customer_churn.xlsx')
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...  Month-to-month
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...  Month-to-month
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...  Month-to-month
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...  Month-to-month
#
# ...

# %%
df.columns
# Out:
# Index(['CustomerID', 'Count', 'Country', 'State', 'City', 'Zip Code',
#        'Lat Long', 'Latitude', 'Longitude', 'Gender', 'Senior Citizen',
#        'Partner', 'Dependents', 'Tenure Months', 'Phone Service',
#        'Multiple Lines', 'Internet Service', 'Online Security',
#        'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV',
#        'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method',
#        'Monthly Charges', 'Total Charges', 'Churn Label', 'Churn Value',
#        'Churn Score', 'CLTV', 'Churn Reason'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# CustomerID              0
# Count                   0
# Country                 0
# State                   0
# City                    0
# Zip Code                0
# Lat Long                0
# Latitude                0
# Longitude               0
# Gender                  0
# Senior Citizen          0
# Partner                 0
# Dependents              0
# Tenure Months           0
# Phone Service           0
# Multiple Lines          0
# Internet Service        0
# Online Security         0
# Online Backup           0
# Device Protection       0
# Tech Support            0
# Streaming TV            0
# Streaming Movies        0
# Contract                0
# Paperless Billing       0
# Payment Method          0
# Monthly Charges         0
# Total Charges           0
# Churn Label             0
# Churn Value             0
# Churn Score             0
# CLTV                    0
# Churn Reason         5174
# dtype: int64

# %%
df.shape
# Out:
# (7043, 33)

# %%
df.describe()
# Out:
#         Count      Zip Code     Latitude    Longitude  Tenure Months  \
# count  7043.0   7043.000000  7043.000000  7043.000000    7043.000000
# mean      1.0  93521.964646    36.282441  -119.798880      32.371149
# std       0.0   1865.794555     2.455723     2.157889      24.559481
# min       1.0  90001.000000    32.555828  -124.301372       0.000000
# 25%       1.0  92102.000000    34.030915  -121.815412       9.000000
# 50%       1.0  93552.000000    36.391777  -119.730885      29.000000
# 75%       1.0  95351.000000    38.224869  -118.043237      55.000000
# max       1.0  96161.000000    41.962127  -114.192901      72.000000
#
#        Monthly Charges  Churn Value  Churn Score         CLTV
# count      7043.000000  7043.000000  7043.000000  7043.000000
# mean         64.761692     0.265370    58.699418  4400.295755
# std          30.090047     0.441561    21.525131  1183.057152
# min          18.250000     0.000000     5.000000  2003.000000
# ...

# %%
df.dtypes
# Out:
# CustomerID            object
# Count                  int64
# Country               object
# State                 object
# City                  object
# Zip Code               int64
# Lat Long              object
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior Citizen        object
# Partner               object
# Dependents            object
# Tenure Months          int64
# Phone Service         object
# Multiple Lines        object
# Internet Service      object
# Online Security       object
# Online Backup         object
# Device Protection     object
# Tech Support          object
# Streaming TV          object
# Streaming Movies      object
# Contract              object
# Paperless Billing     object
# Payment Method        object
# Monthly Charges      float64
# Total Charges         object
# Churn Label           object
# Churn Value            int64
# Churn Score            int64
# CLTV                   int64
# ...

# %%
numeric_columns = df.select_dtypes(include=['number']).columns.tolist()
print(numeric_columns)
# Out:
# ['Count', 'Zip Code', 'Latitude', 'Longitude', 'Tenure Months', 'Monthly Charges', 'Churn Value', 'Churn Score', 'CLTV']

# %%
df.head(5)
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...  Month-to-month
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...  Month-to-month
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...  Month-to-month
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...  Month-to-month
#
# ...

# %%
nonnumeric_columns = df.select_dtypes(exclude= ['number'])
nonnumeric_columns.nunique()
# Out:
# CustomerID           7043
# Country                 1
# State                   1
# City                 1129
# Lat Long             1652
# Gender                  2
# Senior Citizen          2
# Partner                 2
# Dependents              2
# Phone Service           2
# Multiple Lines          3
# Internet Service        3
# Online Security         3
# Online Backup           3
# Device Protection       3
# Tech Support            3
# Streaming TV            3
# Streaming Movies        3
# Contract                3
# Paperless Billing       2
# Payment Method          4
# Total Charges        6531
# Churn Label             2
# Churn Reason           20
# dtype: int64

# %%
binary_cols = [col for col in df.columns if df[col].nunique() == 2]

for col in binary_cols:
    print(f"{col}: {df[col].unique()}")
# Out:
# Gender: ['Male' 'Female']
# Senior Citizen: ['No' 'Yes']
# Partner: ['No' 'Yes']
# Dependents: ['No' 'Yes']
# Phone Service: ['Yes' 'No']
# Paperless Billing: ['Yes' 'No']
# Churn Label: ['Yes' 'No']
# Churn Value: [1 0]

# %%
three_level = [col for col in df.columns if df[col].nunique() == 3]

for col in three_level:
    print(f"{col}: {df[col].unique()}")
# Out:
# Multiple Lines: ['No' 'Yes' 'No phone service']
# Internet Service: ['DSL' 'Fiber optic' 'No']
# Online Security: ['Yes' 'No' 'No internet service']
# Online Backup: ['Yes' 'No' 'No internet service']
# Device Protection: ['No' 'Yes' 'No internet service']
# Tech Support: ['No' 'Yes' 'No internet service']
# Streaming TV: ['No' 'Yes' 'No internet service']
# Streaming Movies: ['No' 'Yes' 'No internet service']
# Contract: ['Month-to-month' 'Two year' 'One year']

# %% [markdown]
# EDA SUMMARY – FEATURE ANALYSIS & DECISIONS
#
# Dataset Overview
#
# Rows: 7,043
# Columns: 33
#
# Problem Type: Binary classification (Customer Churn)
#
# The target variable is customer churn behavior.
#
# 🎯 TARGET DEFINITION
# Target Variable
#
# Churn Value (0 = No churn, 1 = Churn)
#
# Churn Label is the string version of the target.
# Only Churn Values ​​will be used during the modeling phase.
#
# ⚠️ Due to the risk of target leakage, no columns related to the target will be included in the feature set.
#
# 🗑 COLUMNS TO BE DROPPED (REASONED)
#
# These columns cannot be model inputs:
#
# Column	Reason
# CustomerID	Unique identifier, no predictive value
# Zip Code	High cardinality, weak semantic meaning
# Country	Single unique value (California only)
# State	Single unique value
# City	Very high cardinality, not API-friendly
# Lat Long	Redundant representation
# Latitude	Redundant / low business relevance
# Longitude	Redundant / low business relevance
# Churn Reason	Target leakage (only known after churn)
# Churn Label	Target duplicate (string version)
#
# These columns have been identified in EDA,
# they will be dropped during preprocessing.
#
# 🔢 NUMERICAL FEATURES
# Direct Numerical Features
#
# Tenure Months
#
# Monthly Charges
#
# CLTV
#
# Churn Score
#
# Special Case: Total Charges
#
# Stored as string
#
# Contains blank values " " for customers with Tenure = 0
#
# Represents a logical edge case, not random missing data
#
# 📌 Preprocessing Plan:
#
# Convert to float
#
# Blank values → 0
#
# 🔘 BINARY CATEGORICAL FEATURES (BINARY ENCODING)
#
# These features have two meaningful states and will be mapped to 0/1:
#
# Feature
# Gender
# Senior Citizen
# Partner
# Dependents
# Phone Service
# Paperless Billing
#
# 📌 Binary mapping preferred over one-hot encoding to avoid unnecessary dimensionality.
#
# 🧩 MULTI-CLASS CATEGORICAL FEATURES (ONE-HOT ENCODING)
#
# These features have 3+ meaningful categories and require one-hot encoding:
#
# Feature
# Multiple Lines
# Internet Service
# Online Security
# Online Backup
# Device Protection
# Tech Support
# Streaming TV
# Streaming Movies
# Contract
# Payment Method
#
# 📌 Categories such as No internet service and No phone service
# are treated as separate, meaningful classes.
#
# 🧠 FINAL FEATURE STRATEGY
#
# EDA phase:
# → Identify data issues and modeling decisions
#
#
# This ensures:
#
# Train / predict consistency
#
# Reproducibility
#
# Production safety
